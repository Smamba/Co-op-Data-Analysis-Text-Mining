# %%
#merge the seperate sheets into one sheet of excel

# %%
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Economics-BE\\20163545-BE-ESP Free Response.XLSX")

# %%
df1=pd.DataFrame({"Respondent ID":4,"Major:Accounting","Conc:5COP","Class":SR,"Citizenship_Status":Domestic,"Co-op#":Third,"Feedback"},index=[0,1,2,3,4,5,6])
# Out:
#   Input In [168]
#     df1=pd.DataFrame({"Respondent ID":4,"Major:Accounting","Conc:5COP","Class":SR,"Citizenship_Status":Domestic,"Co-op#":Third,"Feedback"},index=[0,1,2,3,4,5,6])
#                                                           ^
# SyntaxError: invalid syntax

# %%
print(df1)
# Out:
#                     0
# 0                Conc
# 1            Feedback
# 2               Class
# 3               Major
# 4       Respondent ID
# 5  Citizenship_Status
# 6              Co-op#

# %%
df2=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Business and Economics-BBE\\AY_2020-BBE-ESP_Free_Response.xlsx")

# %%
df3=pd.DataFrame({"Respondent ID","Major","Conc","Class","Citizenship_Status","Co-op#","Feedback"},index=[0,1,2,3,4,5,6])

# %%
print(df3)
# Out:
#                     0
# 0                Conc
# 1            Feedback
# 2               Class
# 3               Major
# 4       Respondent ID
# 5  Citizenship_Status
# 6              Co-op#

# %%
df=pd.concat([df1,df3],axis=1,ignore_index=False)

# %%
print(df)
# Out:
#                     0                   0
# 0                Conc                Conc
# 1            Feedback            Feedback
# 2               Class               Class
# 3               Major               Major
# 4       Respondent ID       Respondent ID
# 5  Citizenship_Status  Citizenship_Status
# 6              Co-op#              Co-op#

# %%
df.head()
# Out:
#                0              0
# 0           Conc           Conc
# 1       Feedback       Feedback
# 2          Class          Class
# 3          Major          Major
# 4  Respondent ID  Respondent ID

# %%
df.to_excel('output_merge.xlsx',engine='xlsxwriter')

# %%
# working code for merging sheets in excel 2020

# %%
import pandas as pd

# %%
filepath= ('C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Economics-BE\\20181525-BE-ESP Free Response.xlsx')

# %%
df1_dict=pd.read_excel(filepath,sheet_name=None)

# %%
df1_all=pd.concat(df1_dict.values(),ignore_index=True)

# %%
print(df1_all)
# Out:
#     IMPORTANT: The data in this file has not been reviewed for confidential, sensitive, or FERPA protected information.  Identifying characteristics including but not limited to company information, manager/supervisor names, and student information must be redacted before this information can be shared.  Responsibility for the confidential dissemination of this information rests with the sender.   \
# 0                                         Responder ID
# 1                                                  991
# 2                                                  995
# 3                                                  997
# 4                                                  606
# ..                                                 ...
# 127                                               1111
# 128                                                671
# 129                                                588
# 130                                               2052
# ...

# %%
df1_all.head()
# Out:
#   IMPORTANT: The data in this file has not been reviewed for confidential, sensitive, or FERPA protected information.  Identifying characteristics including but not limited to company information, manager/supervisor names, and student information must be redacted before this information can be shared.  Responsibility for the confidential dissemination of this information rests with the sender.   \
# 0                                       Responder ID
# 1                                                991
# 2                                                995
# 3                                                997
# 4                                                606
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     Work Terms    College      Major       Conc      Class
# 1  201815-201825         BE       ECON       5COP         PJ
# 2  201815-201825         BE       ECON       5COP         JR
# 3  201815-201825         BE       ECON       5COP         JR
# ...

# %%
df1_all.to_excel('output_20181525-BE-ESP Free Response_merge.xlsx',engine='xlsxwriter')

# %%
# Working code to merge 2019 excel in one sheet

# %%
import pandas as pd

# %%
filepath= ('C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Business-B\\20181525-B-ESP Free Response.xlsx')

# %%
df4_dict=pd.read_excel(filepath,sheet_name=None)

# %%
df4_all=pd.concat(df4_dict.values(),ignore_index=True)

# %%
print(df4_all)
# Out:
#       Responder ID     Work Terms College Major  Conc Class  \
# 0              987  201815-201825       B   FIN  4COP    SR
# 1              427  201815-201825       B   FIN  5COP    PJ
# 2              428  201815-201825       B   FIN  5COP    JR
# 3              988  201815-201825       B  MKTG  4COP    SR
# 4             1648  201815-201825       B   BAE  5COP    SR
# ...            ...            ...     ...   ...   ...   ...
# 3793           450  201815-201825       B  ACCT  5COP    JR
# 3794           745  201815-201825       B  ACCT  5COP    SR
# 3795           746  201815-201825       B  ACCT  5COP    SR
# 3796           983  201815-201825       B   MIS  5COP    SR
# 3797           898  201815-201815       B  ACCT  4COP    SR
#
#      Citizenship Status Co-op #  \
# 0            US Citizen    Only
# 1            US Citizen  Second
# 2            US Citizen   Third
# 3            US Citizen    Only
# 4            US Citizen   Third
# ...                 ...     ...
# ...

# %%
df4_all.head()
# Out:
#    Responder ID     Work Terms College Major  Conc Class Citizenship Status  \
# 0           987  201815-201825       B   FIN  4COP    SR         US Citizen
# 1           427  201815-201825       B   FIN  5COP    PJ         US Citizen
# 2           428  201815-201825       B   FIN  5COP    JR         US Citizen
# 3           988  201815-201825       B  MKTG  4COP    SR         US Citizen
# 4          1648  201815-201825       B   BAE  5COP    SR         US Citizen
#
#   Co-op #                                           Feedback  \
# 0    Only  One of the main reasons I choose to attend Dre...
# 1  Second  This co-op helped me recognize that I want to ...
# 2   Third  One aspect of this co-op experience that relat...
# 3    Only  I know I’m going to be an entrepreneur. I’ve n...
# 4   Third  One goal I have coming to Drexel was to figure...
#
#   In returning to classes, what do you want to learn/focus on?  \
# 0                                                NaN
# ...

# %%
df4_all.to_excel('output_20181525-B-ESP Free Response.xlsx',engine='xlsxwriter')

# %%
# Remove stop words from the merged sheet

# %%
import pandas as pd
from nltk.corpus import stopwords

# %%
df5=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Business and Economics-BBE\\output_2019_merge.xlsx")

# %%
stop_words = set(stopwords.words("english"))

# %%
print(stop_words)
# Out:
# {'who', "shouldn't", 'an', 'we', 'before', 'had', 'those', "doesn't", 'by', 'mustn', 'his', 'them', 'at', 've', "wasn't", 'shouldn', 'nor', 'very', 'don', 'ain', 'being', 'same', 'against', 'him', 'down', 'wouldn', "she's", 're', 'our', 'above', 'herself', 'that', 'under', 'will', "couldn't", 'while', "you're", 'hers', 'itself', 'over', 'been', 'its', 'below', 'to', 'll', "won't", 'how', 'and', 'but', 'more', 'there', 'm', 'won', 'again', 'couldn', 'she', 'any', "you've", 'few', 'after', "it's", 'only', 'doesn', 'me', 'which', 'this', "don't", 'ourselves', "wouldn't", 'some', 'do', 'once', 'ma', 'from', "hasn't", 'were', 'yourselves', 'if', 'then', 'off', 'doing', 'about', 'shan', 'other', 'didn', "hadn't", 'yourself', 'has', 'on', 'between', 'up', 'during', 'out', 'be', 'having', "haven't", 'mightn', 'when', 'no', 'theirs', 'than', "weren't", "should've", 'should', 'the', "didn't", 's', 'did', 'with', 'all', 'my', 'too', 'further', 'each', 'whom', 'in', 'myself', 'their', 'ours', 'a
# ...

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Swati\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.util import ngrams

# %%
n=1

# %%
unigrams=ngrams(df5["Feedback"].str.split(),n)

# %%
for token in unigrams:
    print(token)
# Out:
# (['I', 'wanted', 'to', 'get', 'more', 'hands', 'on', 'experience', 'in', 'tax', 'return', 'preparation', 'along', 'with', 'planning.', 'This', 'co-op', 'has', 'allowed', 'me', 'to', 'do', 'both', 'with', 'seniors', 'and', 'partners', 'explaining', 'different', 'things', 'to', 'provide', 'me', 'with', 'more', 'knowledge', 'i', 'can', 'use', 'in', 'the', 'future.', 'along', 'with', 'this', 'i', 'wanted', 'to', 'be', 'able', 'to', 'find', 'a', 'place', 'i', 'could', 'end', 'up', 'working', 'for', 'and', 'enjoy', 'my', 'time', 'and', 'i', 'did.'],)
# ...

# %%
print(token)
# Out:
# (['nan'],)

# %%
tokenize_words_without_stopwords=[]

# %%
for word in tokenize_words:
    if word not in tuple(stop_words):
         tokenize_words_without_stopwords.append(word)

# %%
 print(tokenize_words_without_stopwords)
# Out:
# [['nan']]

# %%
# try anothe code for tokenization

# %%
import pandas as pd

# %%
import nltk

# %%
df7=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Business and Economics-BBE\\output_2019_merge.xlsx")

# %%
df7.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0           0          2181  Spring/Summer       B  ACCT  5COP    SR
# 1           1            72    Fall/Winter       B  ACCT  5COP    SR
# 2           2            74    Fall/Winter       B   MIS  5COP    SR
# 3           3          5586  Spring/Summer       B   FIN  5COP    SR
# 4           4          2366  Spring/Summer       B   FIN  5COP    SR
#
#   Citizenship Status      Co-op #  \
# 0           Domestic  Third/Final
# 1           Domestic  Third/Final
# 2           Domestic  Third/Final
# 3           Domestic       Second
# 4           Domestic  Third/Final
#
#                                             Feedback
# 0  I wanted to get more hands on experience in ta...
# 1  Ever since I began pursuing a career in accoun...
# 2  This co-op wasn't as beneficial as my first co...
# 3  I learned how to troubleshoot Amazon's network...
# 4  An aspect of this co-op experience that relate...

# %%
df7['Feedback'].dropna(inplace=True)

# %%
df7['Feedback'] = df7['Feedback'].astype(str)

# %%
df7.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0           0          2181  Spring/Summer       B  ACCT  5COP    SR
# 1           1            72    Fall/Winter       B  ACCT  5COP    SR
# 2           2            74    Fall/Winter       B   MIS  5COP    SR
# 3           3          5586  Spring/Summer       B   FIN  5COP    SR
# 4           4          2366  Spring/Summer       B   FIN  5COP    SR
#
#   Citizenship Status      Co-op #  \
# 0           Domestic  Third/Final
# 1           Domestic  Third/Final
# 2           Domestic  Third/Final
# 3           Domestic       Second
# 4           Domestic  Third/Final
#
#                                             Feedback
# 0  I wanted to get more hands on experience in ta...
# 1  Ever since I began pursuing a career in accoun...
# 2  This co-op wasn't as beneficial as my first co...
# 3  I learned how to troubleshoot Amazon's network...
# 4  An aspect of this co-op experience that relate...

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Swati\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def tokenize():
    tokens=nltk.word_tokenize(df5['token'])

# %%
help()
# Out:
# Welcome to Python 3.9's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.9/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> def tokenize
# No Python documentation found for 'def tokenize'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help> def
# Function definitions
# ********************
#
# A function definition defines a user-defined function object (see
# ...

# %%
return [w for w in tokens if w.isalpha()]
# Out:
#   Input In [23]
#     return [w for w in tokens if w.isalpha()]
#     ^
# SyntaxError: 'return' outside function

# %%
df5['Feedback'] = word.lower() for word in text.split() if word.lower() not in stop
# Out:
#   Input In [134]
#     df5['Feedback'] = word.lower() for word in text.split() if word.lower() not in stop
#                                    ^
# SyntaxError: invalid syntax

# %%
df5.head()

# %%
# remove special characters from the merged data

# %%
import pandas as pd
import re

# %%
df6=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Business-B\\output_20163545-B-ESP Free Response_merge.xlsx")

# %%
df6['Feedback']=df6["Feedback"].str.replace(r'\W',"")
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_17668\3952288125.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df6['Feedback']=df6["Feedback"].str.replace(r'\W',"")

# %%
print(df6)
# Out:
#       Unnamed: 0  Responder ID     Work Terms College Major   Conc Class  \
# 0              0          2301  201635-201645       B   ACCT  5COP    SR
# 1              1          2311  201635-201645       B    BAE  5COP    JR
# 2              2          2318  201635-201645       B    FIN  5COP    JR
# 3              3          2168  201625-201635       B   ACCT  5COP    JR
# 4              4          2343  201635-201645       B   ACCT  5COP    SR
# ...          ...           ...            ...     ...    ...   ...   ...
# 4700        4700          5327  201635-201645       B    FIN  5COP    PJ
# 4701        4701          5333  201635-201645       B   ACCT  5COP    SR
# 4702        4702          5334  201635-201645       B   ACCT  5COP    JR
# 4703        4703          2300  201635-201635       B   MKTG  5COP    JR
# 4704        4704          2300  201645-201645       B   MKTG  5COP    JR
#
#          Citizenship      Co-op #  \
# 0         US Citizen  Third/Final
# ...

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major   Conc Class  \
# 0           0          2301  201635-201645       B   ACCT  5COP    SR
# 1           1          2311  201635-201645       B    BAE  5COP    JR
# 2           2          2318  201635-201645       B    FIN  5COP    JR
# 3           3          2168  201625-201635       B   ACCT  5COP    JR
# 4           4          2343  201635-201645       B   ACCT  5COP    SR
#
#       Citizenship      Co-op #  \
# 0      US Citizen  Third/Final
# 1      US Citizen  Third/Final
# 2      US Citizen        First
# 3      US Citizen  Third/Final
# 4  Non US Citizen  Third/Final
#
#                                             Feedback
# 0  Iplantostrengthenmyweaknessesinwritingreportsf...
# 1  ThisworkstowardsaprofessionalgoalIhavebecauseI...
# 2  Mycoopexperiencerelatesheavilytomygoalofbecomi...
# 3  Iwasthinkingofgoingintopublicauditbutchangedmy...
# 4  MymajoratDrexelLebowisAccountingbutIwantcareer...

# %%
df6.to_excel('Output_spl_2019.xlsx',engine='xlsxwriter')

# %%
import numpy as np

# %%
df6=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Economics-BE\\output_20163545-BE-ESP Free Response_merge.xlsx")

# %%
d1=pd.DataFrame(df6)

# %%
print(d1)
# Out:
#        0 Responder ID    Work Terms  College Major  Conc Class  \
# 0      1         2316  201635-201645      BE  ECON  5COP    SR
# 1      2         2414  201635-201645      BE  ECON  5COP    SR
# 2      3         2501  201635-201645      BE  ECON  5COP    SR
# 3      4         2523  201635-201645      BE  BAEC  5COP    SR
# 4      5         5349  201645-201645      BE  ECON  5COP    SR
# ..   ...          ...            ...     ...   ...   ...   ...
# 420  421         5115  201635-201645      BE  ECON  5COP    PJ
# 421  422         5117  201635-201645      BE  ECON  5COP    SO
# 422  423         5126  201635-201645      BE  ECON  5COP    JR
# 423  424         5147  201635-201645      BE  ECON  5COP    PJ
# 424  425         5190  201635-201645      BE  ECON  4COP    SR
#
#         Citizenship      Co-op #  \
# 0        US Citizen  Third/Final
# 1        US Citizen  Third/Final
# 2        US Citizen  Third/Final
# 3        US Citizen  Third/Final
# 4        US Citizen  Third/Final
# ...

# %%
d1.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Responder ID, Work Terms, College, Major, Conc, Class, Citizenship Status, Co-op #, Feedback, Coop #, Did your classroom activities prepare you for co-op?, Do you have any suggestions on how to improve your classroom activities to prepare you for your    career?, How did your classroom activities prepare you for co-op? If they didn’t, how were you prepared for co-op?, What coursework did you apply most during your co-op?, In returning to classes, what do you want to learn/focus on?, What skills do you need to develop or improve to better prepare you for your next position?, What would have made this job more interesting to you?]
# Index: []

# %%
d1.dropna(how='all')
# Out:
#       Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0              0          2181  Spring/Summer       B  ACCT  5COP    SR
# 1              1            72    Fall/Winter       B  ACCT  5COP    SR
# 2              2            74    Fall/Winter       B   MIS  5COP    SR
# 3              3          5586  Spring/Summer       B   FIN  5COP    SR
# 4              4          2366  Spring/Summer       B   FIN  5COP    SR
# ...          ...           ...            ...     ...   ...   ...   ...
# 5528        5528          5562  Spring/Summer       B  MKTG  5COP    JR
# 5529        5529          5912  Spring/Summer       B   FIN  5COP    PJ
# 5530        5530          5572  Spring/Summer       B  ACCT  5COP    JR
# 5531        5531          5574  Spring/Summer       B   FIN  5COP    PJ
# 5532        5532          5579  Spring/Summer       B   MIS  5COP    JR
#
#      Citizenship Status      Co-op #  \
# 0              Domestic  Third/Final
# ...

# %%
d1.dropna(axis=1)
# Out:
#       sr.no  Responder ID     Work Terms College Major  Conc Class  \
# 0         0          2181  Spring/Summer       B  ACCT  5COP    SR
# 1         1            72    Fall/Winter       B  ACCT  5COP    SR
# 2         2            74    Fall/Winter       B   MIS  5COP    SR
# 3         3          5586  Spring/Summer       B   FIN  5COP    SR
# 4         4          2366  Spring/Summer       B   FIN  5COP    SR
# ...     ...           ...            ...     ...   ...   ...   ...
# 5528   5528          5562  Spring/Summer       B  MKTG  5COP    JR
# 5529   5529          5912  Spring/Summer       B   FIN  5COP    PJ
# 5530   5530          5572  Spring/Summer       B  ACCT  5COP    JR
# 5531   5531          5574  Spring/Summer       B   FIN  5COP    PJ
# 5532   5532          5579  Spring/Summer       B   MIS  5COP    JR
#
#      Citizenship Status
# 0              Domestic
# 1              Domestic
# 2              Domestic
# 3              Domestic
# 4              Domestic
# ...

# %%
print(d1)
# Out:
#       Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0              0          2181  Spring/Summer       B  ACCT  5COP    SR
# 1              1            72    Fall/Winter       B  ACCT  5COP    SR
# 2              2            74    Fall/Winter       B   MIS  5COP    SR
# 3              3          5586  Spring/Summer       B   FIN  5COP    SR
# 4              4          2366  Spring/Summer       B   FIN  5COP    SR
# ...          ...           ...            ...     ...   ...   ...   ...
# 5528        5528          5562  Spring/Summer       B  MKTG  5COP    JR
# 5529        5529          5912  Spring/Summer       B   FIN  5COP    PJ
# 5530        5530          5572  Spring/Summer       B  ACCT  5COP    JR
# 5531        5531          5574  Spring/Summer       B   FIN  5COP    PJ
# 5532        5532          5579  Spring/Summer       B   MIS  5COP    JR
#
#      Citizenship Status      Co-op #  \
# 0              Domestic  Third/Final
# ...

# %%
d2=d1.dropna(axis=0,how='any')

# %%
d2 = df6[df6['Feedback'].notna()]

# %%
print(d2)

# %%
d2.to_excel('output_20163545-BE-ESP Free Response_merge_clean.xlsx',engine='xlsxwriter')

# %%
d2

# %%
# Pre text processing on 2019 data

# %%
import pandas as pd
import re

# %%
df6=pd.read_excel("C:\\Users\\Swati\\OneDrive\\Desktop\\Swati\\MIS_project\\Student_Goals\\Business-B\\Major_Data\\20181525_ACCT.xlsx")

# %%
# converting to lower case

# %%
from nltk.corpus import stopwords
import string
string.punctuation
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
df6['Feedback'].str.lower()
# Out:
# 0     how one aspect of this co-op experience relate...
# 1     my freshman year, i enrolled at drexel univers...
# 2     i always had an interest in the financial indu...
# 3     it was an absolutely amazing experience at gol...
# 4     one aspect of this co-op that has reflected my...
# 5     it is a great experience working here for thos...
# 6     one of my professional goals is to be a strong...
# 7     one of my professional goals while in drexel i...
# 8     working for kpmg was always a goal of mine. ho...
# 9     one personal goal of mine that i am pursuing a...
# 10    my goal after graduating is to go into public ...
# 11    while working for drexel’s general accounting ...
# 12    being an accounting major, there are many diff...
# 13    personally, this co op helped me on all person...
# 14    i've never been a very outgoing person. i'm no...
# 15    when applying for co-op, i always did want to ...
# 16    i really learned a lot from this position. not...
# ...

# %%
df6['Feedback'] = df6['Feedback'].str.lower()

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0          13           362  201815-201825       B  ACCT  5COP    SR
# 1          15          1665  201815-201825       B  ACCT  5COP    SR
# 2          17          1669  201815-201825       B  ACCT  5COP    JR
# 3          71          1752  201815-201825       B  ACCT  5COP    SR
# 4          72           690  201815-201825       B  ACCT  5COP    SO
#
#   Citizenship Status Co-op #  \
# 0     Non US Citizen  Second
# 1         US Citizen   Third
# 2         US Citizen   Third
# 3     Non US Citizen  Second
# 4         US Citizen   First
#
#                                             Feedback
# 0  how one aspect of this co-op experience relate...
# 1  my freshman year, i enrolled at drexel univers...
# 2  i always had an interest in the financial indu...
# 3  it was an absolutely amazing experience at gol...
# 4  one aspect of this co-op that has reflected my...

# %%
first_s = df6.loc[0, "Feedback"]
print(first_s)
# Out:
# how one aspect of this co-op experience relates to a personal, academic, or professional goal that i am pursuing at drexel. _x000d_
# 	_x000d_
# while studying at drexel university, i had an academic goal of improving my quantitative and computer related technical skills, especially in the financial industry. trading analyst co-op at group one trading lp was an amazing experience where i got great exposures to derivative trading, especially options trading. the position also includes a role of floor clerk and interns usually work to manually enter or adjust the trades and it requires highly quantitative skills sets and strong attention to detail. it is my second co-op experience at a trading firm and therefore i had enough experience and good attention to the details, but i wanted to improve the quantitative skill sets that i haven’t worked on during when i was an accounting major student._x000d_
# ...

# %%
print(df6.iloc[100])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 print(df6.iloc[100])
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1520, in _iLocIndexer._getitem_axis(self, key, axis)
#    1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
# -> 1520 self._validate_integer(key, axis)
#    1522 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1452, in _iLocIndexer._validate_integer(self, key, axis)
#    1450 len_axis = len(self.obj._get_axis(axis))
# ...

# %%
# removing punctuations

# %%
df6["Feedback"] = df6['Feedback'].str.replace('[^\w\s]','')
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_26580\3207046443.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df6["Feedback"] = df6['Feedback'].str.replace('[^\w\s]','')

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0          13           362  201815-201825       B  ACCT  5COP    SR
# 1          15          1665  201815-201825       B  ACCT  5COP    SR
# 2          17          1669  201815-201825       B  ACCT  5COP    JR
# 3          71          1752  201815-201825       B  ACCT  5COP    SR
# 4          72           690  201815-201825       B  ACCT  5COP    SO
#
#   Citizenship Status Co-op #  \
# 0     Non US Citizen  Second
# 1         US Citizen   Third
# 2         US Citizen   Third
# 3     Non US Citizen  Second
# 4         US Citizen   First
#
#                                             Feedback
# 0  how one aspect of this coop experience relates...
# 1  my freshman year i enrolled at drexel universi...
# 2  i always had an interest in the financial indu...
# 3  it was an absolutely amazing experience at gol...
# 4  one aspect of this coop that has reflected my ...

# %%
#removing nan values from the column

# %%
# removing Student,students,drexel,CO-OP

# %%
df6['Feedback'] = df6['Feedback'].str.replace("saw","")
df6['Feedback'] = df6['Feedback'].str.replace("also","")
df6['Feedback'] = df6['Feedback'].str.replace("given","")
df6['Feedback'] = df6['Feedback'].str.replace("x000d","")
df6['Feedback'] = df6['Feedback'].str.replace("day","")
df6['Feedback'] = df6['Feedback'].str.replace("come","")
df6['Feedback'] = df6['Feedback'].str.replace("x000d","")
df6['Feedback'] = df6['Feedback'].str.replace("itx000d","")
df6['Feedback'] = df6['Feedback'].str.replace("postgraduationx000d","")
df6['Feedback'] = df6['Feedback'].str.replace("saw","")
df6['Feedback'] = df6['Feedback'].str.replace("leg","")
df6['Feedback'] = df6['Feedback'].str.replace("sanofi","")
df6['Feedback'] = df6['Feedback'].str.replace("x000d","")
df6['Feedback'] = df6['Feedback'].str.replace("job","")
df6['Feedback'] = df6['Feedback'].str.replace("company","")
df6['Feedback'] = df6['Feedback'].str.replace("wishy","")
df6['Feedback'] = df6['Feedback'].str.replace("washiness","")
df6['Feedback'] = df6['Feedback'].str.replace("taken","")
df6['Feedback'] = df6['Feedback'].str.replace("positionx000d","")
df6['Feedback'] = df6['Feedback'].str.replace("communicationx000d","")
df6['Feedback'] = df6['Feedback'].str.replace("futurex000d","")

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0          13           362  201815-201825       B  ACCT  5COP    SR
# 1          15          1665  201815-201825       B  ACCT  5COP    SR
# 2          17          1669  201815-201825       B  ACCT  5COP    JR
# 3          71          1752  201815-201825       B  ACCT  5COP    SR
# 4          72           690  201815-201825       B  ACCT  5COP    SO
#
#   Citizenship Status Co-op #  \
# 0     Non US Citizen  Second
# 1         US Citizen   Third
# 2         US Citizen   Third
# 3     Non US Citizen  Second
# 4         US Citizen   First
#
#                                             Feedback
# 0  how one aspect of this coop experience relates...
# 1  my freshman year i enrolled at drexel universi...
# 2  i always had an interest in the financial indu...
# 3  it was an absolutely amazing experience at gol...
# 4  one aspect of this coop that has reflected my ...

# %%
import string
mess = 'example'
nopunc=[char for char in mess if char not in string.punctuation]
nopunc=''.join(nopunc)
print(nopunc)
# Out:
# example

# %%
nopunc.split()
# Out:
# ['example']

# %%
clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
def text_process(mess):
    nopunc =[char for char in mess if char not in string.punctuation]
    nopunc=''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
df6['Feedback'] = df6['Feedback'].astype(str).apply(text_process)

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0          13           362  201815-201825       B  ACCT  5COP    SR
# 1          15          1665  201815-201825       B  ACCT  5COP    SR
# 2          17          1669  201815-201825       B  ACCT  5COP    JR
# 3          71          1752  201815-201825       B  ACCT  5COP    SR
# 4          72           690  201815-201825       B  ACCT  5COP    SO
#
#   Citizenship Status Co-op #  \
# 0     Non US Citizen  Second
# 1         US Citizen   Third
# 2         US Citizen   Third
# 3     Non US Citizen  Second
# 4         US Citizen   First
#
#                                             Feedback
# 0  [one, aspect, coop, experience, relates, perso...
# 1  [freshman, year, enrolled, drexel, university,...
# 2  [always, interest, financial, industry, enjoye...
# 3  [absolutely, amazing, experience, goldman, sac...
# 4  [one, aspect, coop, reflected, academic, goals...

# %%
#need to check the below code for lemmatization

# %%
import nltk

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Swati\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Swati\AppData\Roaming\nltk_data...
# True

# %%
wnl = nltk.WordNetLemmatizer()
def WNlemmatization(s):
    text = [wnl.lemmatize(r) for r in s]
    return text
df6['lemm_S']  = df6['Feedback'].apply(lambda x: WNlemmatization(x))

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0          13           362  201815-201825       B  ACCT  5COP    SR
# 1          15          1665  201815-201825       B  ACCT  5COP    SR
# 2          17          1669  201815-201825       B  ACCT  5COP    JR
# 3          71          1752  201815-201825       B  ACCT  5COP    SR
# 4          72           690  201815-201825       B  ACCT  5COP    SO
#
#   Citizenship Status Co-op #  \
# 0     Non US Citizen  Second
# 1         US Citizen   Third
# 2         US Citizen   Third
# 3     Non US Citizen  Second
# 4         US Citizen   First
#
#                                             Feedback  \
# 0  [one, aspect, coop, experience, relates, perso...
# 1  [freshman, year, enrolled, drexel, university,...
# 2  [always, interest, financial, industry, enjoye...
# 3  [absolutely, amazing, experience, goldman, sac...
# 4  [one, aspect, coop, reflected, academic, goals...
#
# ...

# %%
df6.tail()
# Out:
#     Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 48         535           744  201815-201825       B  ACCT  5COP    JR
# 49         539           450  201815-201825       B  ACCT  5COP    JR
# 50         540           745  201815-201825       B  ACCT  5COP    SR
# 51         541           746  201815-201825       B  ACCT  5COP    SR
# 52         543           898  201815-201815       B  ACCT  4COP    SR
#
#    Citizenship Status Co-op #  \
# 48     Non US Citizen   First
# 49         US Citizen   First
# 50     Non US Citizen   First
# 51     Non US Citizen   First
# 52     Non US Citizen    Only
#
#                                              Feedback  \
# 48  [transfer, student, china, personal, goal, com...
# 49  [goal, cpa, cole, trying, narrow, field, accou...
# 50  [experience, working, project, management, off...
# 51  [goal, long, term, take, much, accounting, cla...
# 52  [think, coop, experience, boost, self, confide...
#
# ...

# %%
df6['lemm_S_length'] = df6['lemm_S'].apply(len)

# %%
df6.head()
# Out:
#    Unnamed: 0  Responder ID     Work Terms College Major  Conc Class  \
# 0          13           362  201815-201825       B  ACCT  5COP    SR
# 1          15          1665  201815-201825       B  ACCT  5COP    SR
# 2          17          1669  201815-201825       B  ACCT  5COP    JR
# 3          71          1752  201815-201825       B  ACCT  5COP    SR
# 4          72           690  201815-201825       B  ACCT  5COP    SO
#
#   Citizenship Status Co-op #  \
# 0     Non US Citizen  Second
# 1         US Citizen   Third
# 2         US Citizen   Third
# 3     Non US Citizen  Second
# 4         US Citizen   First
#
#                                             Feedback  \
# 0  [one, aspect, coop, experience, relates, perso...
# 1  [freshman, year, enrolled, drexel, university,...
# 2  [always, interest, financial, industry, enjoye...
# 3  [absolutely, amazing, experience, goldman, sac...
# 4  [one, aspect, coop, reflected, academic, goals...
#
# ...

# %%
df7 = df6.lemm_S.sum()

# %%
print(df7)
# Out:
# ['one', 'aspect', 'coop', 'experience', 'relates', 'personal', 'academic', 'professional', 'goal', 'pursuing', 'drexel', 'studying', 'drexel', 'university', 'academic', 'goal', 'improving', 'quantitative', 'computer', 'related', 'technical', 'skill', 'especially', 'financial', 'industry', 'trading', 'analyst', 'coop', 'group', 'one', 'trading', 'lp', 'amazing', 'experience', 'got', 'great', 'exposure', 'derivative', 'trading', 'especially', 'option', 'trading', 'position', 'includes', 'role', 'floor', 'clerk', 'intern', 'usually', 'work', 'manually', 'enter', 'adjust', 'trade', 'requires', 'highly', 'quantitative', 'skill', 'set', 'strong', 'attention', 'detail', 'second', 'coop', 'experience', 'trading', 'firm', 'therefore', 'enough', 'experience', 'good', 'attention', 'detail', 'wanted', 'improve', 'quantitative', 'skill', 'set', 'havent', 'worked', 'accounting', 'major', 'student', 'derivative', 'instrument', 'highly', 'leveraged', 'security', 'often', 'traded', 'form', 'spread', 
# ...

# %%
len(df6.lemm_S.sum())
# Out:
# 7514

# %%
#Tokenization of the data

# %%
from nltk import ngrams
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk import ngrams
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comments =" ".join(df6['Feedback'].astype(str))

# %%
words =word_tokenize(comments)

# %%
print(words)
# Out:
# ['[', "'one", "'", ',', "'aspect", "'", ',', "'coop", "'", ',', "'experience", "'", ',', "'relates", "'", ',', "'personal", "'", ',', "'academic", "'", ',', "'professional", "'", ',', "'goal", "'", ',', "'pursuing", "'", ',', "'drexel", "'", ',', "'studying", "'", ',', "'drexel", "'", ',', "'university", "'", ',', "'academic", "'", ',', "'goal", "'", ',', "'improving", "'", ',', "'quantitative", "'", ',', "'computer", "'", ',', "'related", "'", ',', "'technical", "'", ',', "'skills", "'", ',', "'especially", "'", ',', "'financial", "'", ',', "'industry", "'", ',', "'trading", "'", ',', "'analyst", "'", ',', "'coop", "'", ',', "'group", "'", ',', "'one", "'", ',', "'trading", "'", ',', "'lp", "'", ',', "'amazing", "'", ',', "'experience", "'", ',', "'got", "'", ',', "'great", "'", ',', "'exposures", "'", ',', "'derivative", "'", ',', "'trading", "'", ',', "'especially", "'", ',', "'options", "'", ',', "'trading", "'", ',', "'position", "'", ',', "'includes", "'", ',', "'role", "'", ',
# ...

# %%
df6['Feedback']=df6['Feedback'].astype(str)

# %%
words =word_tokenize(comments)

# %%
print(words)
# Out:
# ['[', "'one", "'", ',', "'aspect", "'", ',', "'coop", "'", ',', "'experience", "'", ',', "'relates", "'", ',', "'personal", "'", ',', "'academic", "'", ',', "'professional", "'", ',', "'goal", "'", ',', "'pursuing", "'", ',', "'drexel", "'", ',', "'studying", "'", ',', "'drexel", "'", ',', "'university", "'", ',', "'academic", "'", ',', "'goal", "'", ',', "'improving", "'", ',', "'quantitative", "'", ',', "'computer", "'", ',', "'related", "'", ',', "'technical", "'", ',', "'skills", "'", ',', "'especially", "'", ',', "'financial", "'", ',', "'industry", "'", ',', "'trading", "'", ',', "'analyst", "'", ',', "'coop", "'", ',', "'group", "'", ',', "'one", "'", ',', "'trading", "'", ',', "'lp", "'", ',', "'amazing", "'", ',', "'experience", "'", ',', "'got", "'", ',', "'great", "'", ',', "'exposures", "'", ',', "'derivative", "'", ',', "'trading", "'", ',', "'especially", "'", ',', "'options", "'", ',', "'trading", "'", ',', "'position", "'", ',', "'includes", "'", ',', "'role", "'", ',
# ...

# %%
comments1 =" ".join(df7)

# %%
print(comments1)
# Out:
# one aspect coop experience relates personal academic professional goal pursuing drexel studying drexel university academic goal improving quantitative computer related technical skill especially financial industry trading analyst coop group one trading lp amazing experience got great exposure derivative trading especially option trading position includes role floor clerk intern usually work manually enter adjust trade requires highly quantitative skill set strong attention detail second coop experience trading firm therefore enough experience good attention detail wanted improve quantitative skill set havent worked accounting major student derivative instrument highly leveraged security often traded form spread contain multiple trade critical understand net risk position dealing one hundred trade daily basis gained exceptional experience risk calculation exchange floor quantitative skill help lot hedge trader position stock instance know size equity stock trader need buy sell calcula
# ...

# %%
words =word_tokenize(comments1)
print(words)
# Out:
# ['one', 'aspect', 'coop', 'experience', 'relates', 'personal', 'academic', 'professional', 'goal', 'pursuing', 'drexel', 'studying', 'drexel', 'university', 'academic', 'goal', 'improving', 'quantitative', 'computer', 'related', 'technical', 'skill', 'especially', 'financial', 'industry', 'trading', 'analyst', 'coop', 'group', 'one', 'trading', 'lp', 'amazing', 'experience', 'got', 'great', 'exposure', 'derivative', 'trading', 'especially', 'option', 'trading', 'position', 'includes', 'role', 'floor', 'clerk', 'intern', 'usually', 'work', 'manually', 'enter', 'adjust', 'trade', 'requires', 'highly', 'quantitative', 'skill', 'set', 'strong', 'attention', 'detail', 'second', 'coop', 'experience', 'trading', 'firm', 'therefore', 'enough', 'experience', 'good', 'attention', 'detail', 'wanted', 'improve', 'quantitative', 'skill', 'set', 'havent', 'worked', 'accounting', 'major', 'student', 'derivative', 'instrument', 'highly', 'leveraged', 'security', 'often', 'traded', 'form', 'spread', 
# ...

# %%
len(words)
# Out:
# 7515

# %%
bow = Counter(words)
bow
# Out:
# Counter({'one': 58,
#          'aspect': 31,
#          'coop': 188,
#          'experience': 105,
#          'relates': 7,
#          'personal': 20,
#          'academic': 16,
#          'professional': 49,
#          'goal': 102,
#          'pursuing': 11,
#          'drexel': 53,
#          'studying': 2,
#          'university': 9,
#          'improving': 2,
#          'quantitative': 5,
#          'computer': 3,
#          'related': 5,
#          'technical': 4,
#          'skill': 33,
#          'especially': 9,
#          'financial': 15,
#          'industry': 6,
#          'trading': 5,
#          'analyst': 3,
#          'group': 6,
#          'lp': 1,
#          'amazing': 7,
#          'got': 17,
#          'great': 24,
#          'exposure': 3,
#          'derivative': 2,
#          'option': 7,
#          'position': 46,
#          'includes': 2,
#          'role': 8,
#          'floor': 3,
#          'clerk': 1,
#          'intern': 8,
#          'usually': 4,
# ...

# %%
df9 = pd.DataFrame(bow.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
print(bow)
# Out:
# Counter({'coop': 77, 'work': 64, 'experience': 57, 'able': 48, 'goal': 39, 'skill': 36, 'would': 31, 'team': 28, 'working': 25, 'career': 25, 'time': 23, 'project': 23, 'business': 23, 'future': 23, 'data': 21, 'one': 21, 'different': 21, 'want': 19, 'opportunity': 19, 'help': 19, 'allowed': 19, 'helped': 18, 'really': 18, 'drexel': 17, 'finance': 17, 'got': 17, 'like': 17, 'well': 17, 'professional': 17, 'class': 16, 'get': 16, 'thing': 16, 'improve': 15, 'learn': 15, 'position': 15, 'role': 14, 'always': 14, 'client': 14, 'communication': 14, 'pursue': 13, 'learned': 13, 'field': 13, 'financial': 13, 'aspect': 13, 'industry': 12, 'made': 12, 'see': 11, 'better': 11, 'student': 11, 'knowledge': 11, 'use': 11, 'lot': 10, 'something': 10, 'way': 10, 'gave': 10, 'used': 10, 'wanted': 10, 'understand': 10, 'economics': 10, 'operation': 9, 'important': 9, 'firm': 9, 'know': 9, 'software': 9, 'done': 9, 'power': 9, 'bi': 9, 'world': 8, 'set': 8, 'value': 8, 'part': 8, 'taught': 8, 'need':
# ...

# %%
df6['Feedback'] = df6['Feedback'].str.replace("x000d","")

# %%
from collections import Counter
from itertools import chain

# %%
# split words into lists
s = df6['Feedback'].str.split().tolist() # [s.split() for s in df['Col2'].tolist()]
# compute global word frequency
w = Counter(chain.from_iterable(s))
# filter, join, and re-assign
df6['Feedback'] = [' '.join([j for j in i if w[j] > 1]) for i in s]

# %%
# Lower frequency data to be removed

# %%
list_freq = df9['frequency']

# %%
print("The word freq list : " + str(list_freq))
# Out:
# The word freq list : 31      223
# 7       184
# 24      168
# 69      119
# 34      119
#        ...
# 1248      1
# 1253      1
# 1254      1
# 1255      1
# 2082      1
# Name: frequency, Length: 2083, dtype: int64

# %%
K=30

# %%
res = [ i for i in list_freq if list_freq.count(i) > K]
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_41668\288993875.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   res = [ i for i in list_freq if list_freq.count(i) > K]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [476], in <cell line: 1>()
# ----> 1 res = [ i for i in list_freq if list_freq.count(i) > K]
#
# Input In [476], in <listcomp>(.0)
# ----> 1 res = [ i for i in list_freq if list_freq.count(i) > K]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1976, in Series.count(self, level)
#    1968     warnings.warn(
#    1969         "Using the level keyword in DataFrame and Series aggregations is "
#    1970         "deprecated and will be removed in a future version. Use groupby "
# ...

# %%
print("The list removing elements less than and equal K  : " + str(res))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [477], in <cell line: 1>()
# ----> 1 print("The list removing elements less than and equal K  : " + str(res))
#
# NameError: name 'res' is not defined

# %%
print(df6)
# Out:
#     Unnamed: 0  Responder ID     Work Terms College Major   Conc Class  \
# 0            0          2301  201635-201645       B   ACCT  5COP    SR
# 1            3          2168  201625-201635       B   ACCT  5COP    JR
# 2            4          2343  201635-201645       B   ACCT  5COP    SR
# 3           12          2169  201625-201635       B   ACCT  5COP    JR
# 4           52          2663  201635-201645       B   ACCT  5COP    SR
# ..         ...           ...            ...     ...    ...   ...   ...
# 74         664          5293  201635-201645       B   ACCT  5COP    JR
# 75         665          5296  201635-201645       B   ACCT  5COP    JR
# 76         666          5326  201635-201645       B   ACCT  5COP    JR
# 77         668          5333  201635-201645       B   ACCT  5COP    SR
# 78         669          5334  201635-201645       B   ACCT  5COP    JR
#
#                    Citizenship      Co-op #  \
# 0                   US Citizen  Third/Final
# ...

# %%
df6['Feedback'] = df6['Feedback'].str.replace("work","")

# %%
df6['Feedback'] = df6['Feedback'].str.replace("one","")

# %%
df6['Feedback'] = df6['Feedback'].str.replace("also","")

# %%
df6['Feedback'] = df6['Feedback'].str.replace("ing","")

# %%
df6['Feedback'] = df6['Feedback'].str.replace("job","")

# %%
df6['Feedback'] = df6['Feedback'].str.replace("able","")

# %%
df6['Feedback'] = df6['Feedback'].str.replace("al","")

# %%
print(df9)
# Out:
#             word  frequency
# 2           coop        188
# 39          work        120
# 3     experience        105
# 8           goal        102
# 59    accounting         97
# ...          ...        ...
# 1049        scdc          1
# 1050      online          1
# 1051         srm          1
# 1052   saporacle          1
# 1804       boost          1
#
# [1805 rows x 2 columns]

# %%
df9.to_excel('output_20181525_ACCT_words.xlsx',engine='xlsxwriter')

# %%
df9['word'] = df9['word'].replace(regex=['arriv'],value='arrive')

# %%
df9['word'] = df9['word'].replace(regex=['capit'],value='capital')

# %%
df9['word'] = df9['word'].replace(regex=['theink'],value='think')

# %%
df9['word'] = df9['word'].replace(regex=['learnhead'],value='learned')

# %%
df9['word'] = df9['word'].replace(regex=['the'],value='nan')

# %%
df0 =df9.head(20) #20 is top20

# %%
print(df0)
# Out:
#              word  frequency
# 31           coop        223
# 7            work        184
# 24     accounting        168
# 69           goal        119
# 34     experience        119
# 12            job         91
# 99            one         88
# 129       company         87
# 139         would         86
# 141           tax         85
# 251          time         85
# 67          x000d         81
# 127       working         81
# 262          able         76
# 157     different         75
# 149          also         72
# 146  professional         71
# 78           like         69
# 25           want         69
# 80          skill         65

# %%
sns.barplot(x='frequency',y='word',data=df9.head(20))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
bow2 =Counter(ngrams(words,2))
bow2
# Out:
# Counter({('one', 'aspect'): 18,
#          ('aspect', 'coop'): 19,
#          ('coop', 'relates'): 11,
#          ('relates', 'professional'): 7,
#          ('professional', 'career'): 5,
#          ('career', 'opportunity'): 2,
#          ('opportunity', 'analyze'): 1,
#          ('analyze', 'investment'): 1,
#          ('investment', 'opportunity'): 1,
#          ('opportunity', 'company'): 1,
#          ('company', 'major'): 2,
#          ('major', 'finance'): 5,
#          ('finance', 'international'): 2,
#          ('international', 'business'): 9,
#          ('business', 'going'): 1,
#          ('going', 'first'): 4,
#          ('first', 'day'): 4,
#          ('day', 'coop'): 1,
#          ('coop', 'analyst'): 1,
#          ('analyst', 'venture'): 1,
#          ('venture', 'capital'): 1,
#          ('capital', 'firm'): 1,
#          ('firm', 'little'): 1,
#          ('little', 'experience'): 1,
#          ('experience', 'go'): 1,
#          ('go', 'arm'): 1,
# ...

# %%
d1_bi = pd.DataFrame(bow2.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
sns.barplot(x='frequency',y='word',data=d1_bi.head(20))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
sns.barplot(x='frequency',y='word',data=d1_bi.tail(20))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
d0_n = pd.DataFrame(bow.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
sns.barplot(x='frequency',y='word',data=d0_n.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
bow3 =Counter(ngrams(words,3))
bow3
# Out:
# Counter({('one', 'aspect', 'coop'): 10,
#          ('aspect', 'coop', 'relates'): 6,
#          ('coop', 'relates', 'professional'): 4,
#          ('relates', 'professional', 'career'): 1,
#          ('professional', 'career', 'opportunity'): 1,
#          ('career', 'opportunity', 'analyze'): 1,
#          ('opportunity', 'analyze', 'investment'): 1,
#          ('analyze', 'investment', 'opportunity'): 1,
#          ('investment', 'opportunity', 'company'): 1,
#          ('opportunity', 'company', 'major'): 1,
#          ('company', 'major', 'finance'): 1,
#          ('major', 'finance', 'international'): 1,
#          ('finance', 'international', 'business'): 2,
#          ('international', 'business', 'going'): 1,
#          ('business', 'going', 'first'): 1,
#          ('going', 'first', 'day'): 1,
#          ('first', 'day', 'coop'): 1,
#          ('day', 'coop', 'analyst'): 1,
#          ('coop', 'analyst', 'venture'): 1,
#          ('analyst', 'venture', 'capital'): 1,
# ...

# %%
d1_tri = pd.DataFrame(bow3.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
sns.barplot(x='frequency',y='word',data=d1_tri.head(20))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df6['Classroom_Activities_Suggestion_Tokenize_Conc'] = df_stud2019['Classroom_Activities_Suggestion_Tokenize_Conc'].replace(regex=['expel'], value='excel')

# %%
sns.barplot(x='frequency',y='word',data=d1_tri.tail(20))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Swati\AppData\Roaming\nltk_data...
# True

# %%
print(df7)
# Out:
# ['felt', 'lot', 'american', 'culture', 'working', 'estee', 'lauder', 'keystone', 'plant', 'first', 'knowledge', 'difference', 'company', 'hierarchy', 'culture', 'usa', 'lot', 'chance', 'communicate', 'supervisor', 'work', 'position', 'also', 'lot', 'chance', 'talk', 'line', 'assembler', 'people', 'control', 'quality', 'product', 'lot', 'situation', 'cannot', 'control', 'human', 'resource', 'operation', 'however', 'learned', 'prioritize', 'task', 'ask', 'others', 'cover', 'job', 'cannot', 'handle', 'really', 'liked', 'interacted', 'people', 'plant', 'helped', 'need', 'help', 'problem', 'issue', 'could', 'learn', 'teamwork', 'important', 'achieve', 'good', 'performance', 'operation', 'plant', 'think', 'time', 'management', 'task', 'prioritization', 'skill', 'applied', 'normal', 'life', 'face', 'various', 'problem', 'issue', 'communication', 'skill', 'among', 'employee', 'really', 'basic', 'useful', 'skill', 'work', 'academic', 'team', 'project', 'professional', 'career', 'future', 'fut
# ...

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# Sentiment analysis using TextBlob

# %%
pip install -U textblob-de
# Out:
# ...
#
# ...

# %%
from textblob import TextBlob

# %%
# function to calculate subjectivity

# %%
def getSubjectivity(Feedback):
    return TextBlob(Feedback).sentiment.subjectivity

# %%
# function to calculate polarity

# %%
def getPolarity(Feedback):
    return TextBlob(Feedback).sentiment.polarity

# %%
# function to analyze the feedbacks

# %%
def analysis(score):
    if score<0:
        return 'Negative'
    elif score== 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
final=df6[['Feedback','lemm_S']]

# %%
print(fin_data)
# Out:
#                                               Feedback  \
# 0    ['wanted', 'get', 'hands', 'experience', 'tax'...
# 1    ['ever', 'since', 'began', 'pursuing', 'career...
# 2    ['heading', 'final', 'coop', 'drexel', 'knew',...
# 3    ['able', 'complete', 'second', 'coop', 'accoun...
# 4    ['graduation', 'plan', 'find', 'fulltime', 'po...
# ..                                                 ...
# 115  ['came', 'back', 'school', 'major', 'accountin...
# 116  ['first', 'coop', 'gave', 'good', 'platform', ...
# 117  ['coop', 'kpmg', 'perfect', 'fit', 'personal',...
# 118  ['prior', 'drexel', 'lessons', 'taxation', 'in...
# 119  ['one', 'professional', 'goals', 'become', 'cp...
#
#                                                 lemm_S
# 0    [wanted, get, hand, experience, tax, return, p...
# 1    [ever, since, began, pursuing, career, account...
# 2    [heading, final, coop, drexel, knew, make, sur...
# 3    [able, complete, second, coop, accounting, int...
# ...

# %%
final.head()
# Out:
#                                             Feedback  \
# 0  ['wanted', 'get', 'hands', 'experience', 'tax'...
# 1  ['ever', 'since', 'began', 'pursuing', 'career...
# 2  ['heading', 'final', 'coop', 'drexel', 'knew',...
# 3  ['able', 'complete', 'second', 'coop', 'accoun...
# 4  ['graduation', 'plan', 'find', 'fulltime', 'po...
#
#                                               lemm_S
# 0  [wanted, get, hand, experience, tax, return, p...
# 1  [ever, since, began, pursuing, career, account...
# 2  [heading, final, coop, drexel, knew, make, sur...
# 3  [able, complete, second, coop, accounting, int...
# 4  [graduation, plan, find, fulltime, position, a...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# function to calculate vader sentiment

# %%
def vadersentimentanalysis(Feedback):
    vs = analyzer.polarity_scores(Feedback)
    return vs['compound']

# %%
final['Vader Sentiment'] = final['lemm_S'].apply(vadersentimentanalysis)
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_20572\1012082048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fin_data['Vader Sentiment'] = fin_data['lemm_S'].apply(vadersentimentanalysis)

# %%
# function to analyse

# %%
def vader_analysis(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound <= -0.5 :
        return 'Negative'
    else:
        return 'Neutral'

# %%
final['Vader Analysis'] = final['Vader Sentiment'].apply(vader_analysis)
final.head()
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_20572\995288561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fin_data['Vader Analysis'] = fin_data['Vader Sentiment'].apply(vader_analysis)
#                                             Feedback  \
# 0  ['wanted', 'get', 'hands', 'experience', 'tax'...
# 1  ['ever', 'since', 'began', 'pursuing', 'career...
# 2  ['heading', 'final', 'coop', 'drexel', 'knew',...
# 3  ['able', 'complete', 'second', 'coop', 'accoun...
# 4  ['graduation', 'plan', 'find', 'fulltime', 'po...
#
#                                               lemm_S  Vader Sentiment  \
# 0  [wanted, get, hand, experience, tax, return, p...              0.0
# 1  [ever, since, began, pursuing, career, account...              0.0
# ...

# %%
vader_counts = fin_data['Vader Analysis'].value_counts()
vader_counts
# Out:
# Neutral    120
# Name: Vader Analysis, dtype: int64

# %%
final['Vader Analysis'] = final['Vader Sentiment'].apply(vader_analysis)
final.head()
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_2652\995288561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fin_data['Vader Analysis'] = fin_data['Vader Sentiment'].apply(vader_analysis)
#                                             Feedback  \
# 0  ['felt', 'lot', 'american', 'culture', 'workin...
# 1  ['initial', 'goal', 'learn', 'energy', 'indust...
# 2  ['one', 'aspect', 'experience', 'working', 'pr...
# 3  ['personal', 'professional', 'goal', 'get', 'b...
# 4  ['want', 'become', 'wellrounded', 'work', 'wor...
#
#                                               lemm_S  Vader Sentiment  \
# 0  [felt, lot, american, culture, working, estee,...              0.0
# 1  [initial, goal, learn, energy, industry, find,...              0.0
# ...

# %%
vader_counts = final['Vader Analysis'].value_counts()
vader_counts
# Out:
# Neutral    680
# Name: Vader Analysis, dtype: int64

# %%
final['Vader Analysis'] = final['Vader Sentiment'].apply(vader_analysis)
fin_data.tail()
# Out:
# C:\Users\Swati\AppData\Local\Temp\ipykernel_2652\2926740390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fin_data['Vader Analysis'] = fin_data['Vader Sentiment'].apply(vader_analysis)
#                                               Feedback  \
# 675  ['position', 'organization', 'coordinator', 'w...
# 676  ['transferred', 'associate', 'degree', 'got', ...
# 677  ['work', 'experience', 'fortunate', 'enough', ...
# 678  ['time', 'project', 'home', 'opened', 'eyes', ...
# 679  ['position', 'officially', 'sales', 'intern', ...
#
#                                                 lemm_S  Vader Sentiment  \
# 675  [position, organization, coordinator, wesgold,...              0.0
# ...

# %%
vader_counts = final['Vader Analysis'].value_counts()
vader_counts
# Out:
# Neutral    514
# Name: Vader Analysis, dtype: int64

# %%
print(final)
# Out:
#                                               Feedback  \
# 0    ['plan', 'strengthen', 'weaknesses', 'writing'...
# 1    ['works', 'towards', 'professional', 'goal', '...
# 2    ['experience', 'relates', 'heavily', 'goal', '...
# 3    ['thinking', 'going', 'public', 'audit', 'chan...
# 4    ['major', 'lebow', 'accounting', 'want', 'care...
# ..                                                 ...
# 667  ['professional', 'goal', 'financial', 'analyst...
# 668  ['entire', 'experience', 'actually', '100', 'r...
# 669  ['one', 'aspect', 'would', 'like', 'focus', 'j...
# 670  ['many', 'things', 'mind', 'starting', 'experi...
# 671  ['first', 'international', 'great', 'time', 'k...
#
#                                                 lemm_S  Vader Sentiment  \
# 0    [plan, strengthen, weakness, writing, report, ...              0.0
# 1    [work, towards, professional, goal, want, get,...              0.0
# 2    [experience, relates, heavily, goal, becoming,...              0.0
# ...

# %%
print(df6)
# Out:
#       Responder ID     Work Terms College Major  Conc Class  \
# 0             2181  Spring/Summer       B  ACCT  5COP    SR
# 1               72    Fall/Winter       B  ACCT  5COP    SR
# 2               74    Fall/Winter       B   MIS  5COP    SR
# 3             5586  Spring/Summer       B   FIN  5COP    SR
# 4             2366  Spring/Summer       B   FIN  5COP    SR
# ...            ...            ...     ...   ...   ...   ...
# 1374          5562  Spring/Summer       B  MKTG  5COP    JR
# 1375          5912  Spring/Summer       B   FIN  5COP    PJ
# 1376          5572  Spring/Summer       B  ACCT  5COP    JR
# 1377          5574  Spring/Summer       B   FIN  5COP    PJ
# 1378          5579  Spring/Summer       B   MIS  5COP    JR
#
#      Citizenship Status      Co-op #  \
# 0              Domestic  Third/Final
# 1              Domestic  Third/Final
# 2              Domestic  Third/Final
# 3              Domestic       Second
# 4              Domestic  Third/Final
# ...

# %%
final.to_excel('Senti_output_20173545-B-ESP Free Response_clean.xlsx',engine='xlsxwriter')

# %%
nltk.download('sentiwordnet')
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\Swati\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\sentiwordnet.zip.
# True

# %%
# code to create a bar chart graph for visualization

# %%
# Set the figure size - handy for larger output
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10, 6]
# %config InlineBackend.figure_format = 'retina'

# %%
# Import the pandas library with the usual "pd" shortcut
import pandas as pd
# Create a Pandas series from a list of values ("[]") and plot it:
pd.Series([2014, 2015, 2016, 2017, 2018, 2019, 2020]).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Create a data frame with one column, "ages"
plotdata = pd.DataFrame({"years": [2014, 2015, 2016, 2017, 2018,2019,2020]})
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame()
# Plotting functions:
df.plot.area     
df.plot.barh     
df.plot.density  
df.plot.hist     
df.plot.line    
df.plot.scatter
df.plot.bar     
df.plot.box      
df.plot.hexbin   
df.plot.kde      
df.plot.pie
# Out:
# <bound method PlotAccessor.pie of <pandas.plotting._core.PlotAccessor object at 0x0000019617297400>>

# %%
# Create a sample dataframe with an text index
plotdata = pd.DataFrame(
    {"Year": [2014, 2015, 2016, 2017, 2018,2019,2020]}, 
    index=["ACCT", "ACCT", "ACCT", "ACCT", "ACCT","ACCT","ACCT"])
# Plot a bar chart
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt
plotdata['Year'].plot(kind="bar", title="ACCT chart")

plt.title("Year wise comparison of goals for ACCT major")
plt.xlabel("ACCT major")
plt.ylabel("Data in Years")
# Out:
# Text(0, 0.5, 'Data in Years')

# %%
print(df9)
# Out:
#                word  frequency
# 29             coop        579
# 79             work        397
# 4        accounting        320
# 1              goal        315
# 25       experience        279
# ...             ...        ...
# 2209          clerk          1
# 2208  auditingx000d          1
# 1083  everydayx000d          1
# 2205        closest          1
# 3278      favorable          1
#
# [3279 rows x 2 columns]

# %%
df_word1=df9['word']

# %%
df9.to_excel('output_ACCT_2015.xlsx',engine='xlsxwriter')

# %%
# Create a DataFrame with 3 columns:
plotdata = pd.DataFrame({
    "ACCT_2015":['coop,accounting,goal,experience,time,working,professional,like,career,people,help,tax,make,drexel,really,different,lot,business,skill,think'],
   "ACCT_2016":['coop,accounting,experience,goal,time,like,different,working,career,business,professional,tax,finance,learn,drexel,skill,able,future,people,firm'],
    "ACCT_2017":['coop,accounting,experience,goal,time,working,people,able,help,get,professional,tax,career,like,want,helped,many,drexel,different,skill,cpa'],
    "ACCT_2018":['coop,experience,goal,accounting,career,Drexel,working,professional,help,position,like,future,first,major,opportunity,different,time,project,tax,learned'],
    "ACCT_2019":['coop,work,goal,experience,working,skill,professional,business,time,like,career,learn,different,drexel,team,helped,position,opportunity,help,project,personal,marketing,industry'],
    "ACCT_2020":['coop,work,goal,experience,able,working,skill,professional,business,time,career,learn,different,drexel,team,helped,position,learned,future,opportunity'],
    }, 
    index=["2015", "2016", "2017", "2018", "2019","2020"]
)
plotdata.head()
# Out:
#                                               ACCT_2015  \
# 2015  coop,accounting,goal,experience,time,working,p...
# 2016  coop,accounting,goal,experience,time,working,p...
# 2017  coop,accounting,goal,experience,time,working,p...
# 2018  coop,accounting,goal,experience,time,working,p...
# 2019  coop,accounting,goal,experience,time,working,p...
#
#                                               ACCT_2016  \
# 2015  coop,accounting,experience,goal,time,like,diff...
# 2016  coop,accounting,experience,goal,time,like,diff...
# 2017  coop,accounting,experience,goal,time,like,diff...
# 2018  coop,accounting,experience,goal,time,like,diff...
# 2019  coop,accounting,experience,goal,time,like,diff...
#
#                                               ACCT_2017  \
# 2015  coop,accounting,experience,goal,time,working,p...
# 2016  coop,accounting,experience,goal,time,working,p...
# 2017  coop,accounting,experience,goal,time,working,p...
# 2018  coop,accounting,experience,goal,time,working,p...
# ...
